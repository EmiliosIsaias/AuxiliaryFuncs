# %%
from pynwb import NWBHDF5IO, validate
from nwbwidgets import nwb2widget

# %%
fileName = r"Z:\SC Anatomy paper data\Roller\pyNWB\GADe59_221101.nwb"
io = NWBHDF5IO(fileName, mode='r')
validate(io)
# Out:
# []

# %%
nwb = io.read()

nwb2widget(nwb)
# Out:
# VBox(children=(HBox(children=(Label(value='session_description:', layout=Layout(max_height='40px', max_width='…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\NWB\lib\site-packages\ipywidgets\widgets\widget.py:766, in Widget._handle_msg(self, msg)
#     764         if 'buffer_paths' in data:
#     765             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 766         self.set_state(state)
#     768 # Handle a state request.
#     769 elif method == 'request_state':
#
# File ~\anaconda3\envs\NWB\lib\site-packages\ipywidgets\widgets\widget.py:643, in Widget.set_state(self, sync_data)
#     638         self._send(msg, buffers=echo_buffers)
#     640 # The order of these context managers is important. Properties must
#     641 # be locked when the hold_trait_notification context manager is
#     642 # released and notifications are fired.
# --> 643 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     644     for name in sync_data:
#     645         if name in self.keys:
#
# File ~\anaconda3\envs\NWB\lib\contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File ~\anaconda3\envs\NWB\lib\site-packages\traitlets\traitlets.py:1498, in HasTraits.hold_trait_notifications(self)
#    1496 for changes in cache.values():
#    1497     for change in changes:
# -> 1498         self.notify_change(change)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\ipywidgets\widgets\widget.py:694, in Widget.notify_change(self, change)
#     691     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     692         # Send new state to front-end
#     693         self.send_state(key=name)
# --> 694 super().notify_change(change)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\traitlets\traitlets.py:1513, in HasTraits.notify_change(self, change)
#    1511 def notify_change(self, change):
#    1512     """Notify observers of a change event"""
# -> 1513     return self._notify_observers(change)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\traitlets\traitlets.py:1560, in HasTraits._notify_observers(self, event)
#    1557 elif isinstance(c, EventHandler) and c.name is not None:
#    1558     c = getattr(self, c.name)
# -> 1560 c(event)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\nwbwidgets\base.py:189, in lazy_show_over_data.<locals>.on_selected_index(change)
#     187 def on_selected_index(change):
#     188     if change.new is not None and isinstance(change.owner.children[change.new], widgets.HTML):
# --> 189         children[change.new] = vis2widget(func_(list_[change.new]))
#     190         change.owner.children = children
#
# File ~\anaconda3\envs\NWB\lib\site-packages\nwbwidgets\view.py:122, in nwb2widget(node, neurodata_vis_spec)
#     121 def nwb2widget(node, neurodata_vis_spec=default_neurodata_vis_spec):
# --> 122     return nwb2widget_base(node, neurodata_vis_spec)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\nwbwidgets\base.py:204, in nwb2widget(node, neurodata_vis_spec, **pass_kwargs)
#     202             return lazy_tabs(spec, node)
#     203         elif callable(spec):
# --> 204             visualization = spec(node, neurodata_vis_spec=neurodata_vis_spec, **pass_kwargs)
#     205             return vis2widget(visualization)
#     206 out1 = widgets.Output()
#
# File ~\anaconda3\envs\NWB\lib\site-packages\nwbwidgets\base.py:83, in dict2accordion(d, neurodata_vis_spec, **pass_kwargs)
#      81 def dict2accordion(d: dict, neurodata_vis_spec: dict, **pass_kwargs) -> widgets.Widget:
#      82     if len(d) == 1:
# ---> 83         return nwb2widget(list(d.values())[0], neurodata_vis_spec=neurodata_vis_spec)
#      84     children = [widgets.HTML("Rendering...") for _ in d]
#      85     accordion = widgets.Accordion(children=children, selected_index=None)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\nwbwidgets\base.py:202, in nwb2widget(node, neurodata_vis_spec, **pass_kwargs)
#     200 spec = neurodata_vis_spec[ndtype]
#     201 if isinstance(spec, dict):
# --> 202     return lazy_tabs(spec, node)
#     203 elif callable(spec):
#     204     visualization = spec(node, neurodata_vis_spec=neurodata_vis_spec, **pass_kwargs)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\nwbwidgets\base.py:124, in lazy_tabs(in_dict, node, style)
#     105 """Creates a lazy tab object where multiple visualizations can be used for a single node and are generated on the
#     106 fly
#     107
#    (...)
#     120
#     121 """
#     122 tabs_spec = list(in_dict.items())
# --> 124 children = [tabs_spec[0][1](node)] + [widgets.HTML("Rendering...") for _ in range(len(tabs_spec) - 1)]
#     125 tab = style(children=children)
#     126 [tab.set_title(i, label) for i, (label, _) in enumerate(tabs_spec)]
#
# File ~\anaconda3\envs\NWB\lib\site-packages\nwbwidgets\dynamictablesummary.py:16, in DynamicTableSummaryWidget.__init__(self, table)
#      13 super().__init__()
#      14 self.dynamic_table = table
# ---> 16 self.col_names, self.categorical_cols = infer_columns_to_plot(self.dynamic_table)
#      18 num_entries = len(self.dynamic_table)
#      19 num_columns = len(self.dynamic_table.colnames)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\nwbwidgets\utils\dynamictable.py:73, in infer_columns_to_plot(dynamic_table)
#      59 """Infer which columns can be plotted in summary widgets
#      60
#      61 Parameters
#    (...)
#      68     Columns that can be plotted with the dynamic table summary
#      69 """
#      71 column_names_to_plot = []
# ---> 73 df = dynamic_table.to_dataframe()
#      74 categorical_columns = []
#      75 for name in dynamic_table.colnames:
#      76     # if name not in categorical_cols.keys():  # categorical columns can always be plotted
#
# File ~\anaconda3\envs\NWB\lib\site-packages\hdmf\utils.py:645, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     643 def func_call(*args, **kwargs):
#     644     pargs = _check_args(args, kwargs)
# --> 645     return func(args[0], **pargs)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\hdmf\common\table.py:1112, in DynamicTable.to_dataframe(self, **kwargs)
#    1104 """
#    1105 Produce a pandas DataFrame containing this table's data.
#    1106
#    (...)
#    1109 If exclude is None, this is equivalent to table.get(slice(None, None, None), index=False).
#    1110 """
#    1111 arg = slice(None, None, None)  # select all rows
# -> 1112 sel = self.__get_selection_as_dict(arg, df=True, **kwargs)
#    1113 ret = self.__get_selection_as_df(sel)
#    1114 return ret
#
# File ~\anaconda3\envs\NWB\lib\site-packages\hdmf\common\table.py:963, in DynamicTable.__get_selection_as_dict(self, arg, df, index, exclude, **kwargs)
#     961         raise IndexError(msg) from ve
#     962     else:  # pragma: no cover
# --> 963         raise ve
#     964 except IndexError as ie:
#     965     x = re.match(r"^Index \((.*)\) out of range for \(.*\)$", str(ie))
#
# File ~\anaconda3\envs\NWB\lib\site-packages\hdmf\common\table.py:940, in DynamicTable.__get_selection_as_dict(self, arg, df, index, exclude, **kwargs)
#     937 ret = OrderedDict()
#     938 try:
#     939     # index with a python slice or single int to select one or multiple rows
# --> 940     ret['id'] = self.id[arg]
#     941     for name in self.colnames:
#     942         if name in exclude:
#
# File ~\anaconda3\envs\NWB\lib\site-packages\hdmf\container.py:564, in Data.__getitem__(self, args)
#     563 def __getitem__(self, args):
# --> 564     return self.get(args)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\hdmf\container.py:572, in Data.get(self, args)
#     569 if isinstance(self.data, h5py.Dataset) and isinstance(args, np.ndarray):
#     570     # This is needed for h5py 2.9 compatability
#     571     args = args.tolist()
# --> 572 return self.data[args]
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~\anaconda3\envs\NWB\lib\site-packages\h5py\_hl\dataset.py:766, in Dataset.__getitem__(self, args, new_dtype)
#     763 if new_dtype is None:
#     764     new_dtype = getattr(self._local, 'astype', None)
# --> 766 if self._fast_read_ok and (new_dtype is None):
#     767     try:
#     768         return self._fast_reader.read(args)
#
# File ~\anaconda3\envs\NWB\lib\site-packages\h5py\_hl\base.py:534, in cached_property.__get__(self, obj, cls)
#     531 if obj is None:
#     532     return self
# --> 534 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     535 return value
#
# File ~\anaconda3\envs\NWB\lib\site-packages\h5py\_hl\dataset.py:745, in Dataset._fast_read_ok(self)
#     741 @cached_property
#     742 def _fast_read_ok(self):
#     743     """Is this dataset suitable for simple reading"""
#     744     return (
# --> 745         self._extent_type == h5s.SIMPLE
#     746         and isinstance(self.id.get_type(), (h5t.TypeIntegerID, h5t.TypeFloatID))
#     747     )
#
# File ~\anaconda3\envs\NWB\lib\site-packages\h5py\_hl\base.py:534, in cached_property.__get__(self, obj, cls)
#     531 if obj is None:
#     532     return self
# --> 534 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     535 return value
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~\anaconda3\envs\NWB\lib\site-packages\h5py\_hl\dataset.py:634, in Dataset._extent_type(self)
#     630 @cached_property
#     631 @with_phil
#     632 def _extent_type(self):
#     633     """Get extent type for this dataset - SIMPLE, SCALAR or NULL"""
# --> 634     return self.id.get_space().get_simple_extent_type()
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\h5d.pyx:347, in h5py.h5d.DatasetID.get_space()
#
# ValueError: Invalid dataset identifier (invalid dataset identifier)

# %%
io.close()
